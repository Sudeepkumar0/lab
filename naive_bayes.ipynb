# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score


iris = load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)


model = GaussianNB()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
y_pred

print("Correct Predictions:")
for i in range(len(y_test)):
    if y_pred[i] == y_test[i]:
        print(f"Sample {i}: Predicted = {target_names[y_pred[i]]}, Actual = {target_names[y_test[i]]}")

print("\nWrong Predictions:")
for i in range(len(y_test)):
    if y_pred[i] != y_test[i]:
        print(f"Sample {i}: Predicted = {target_names[y_pred[i]]}, Actual = {target_names[y_test[i]]}")

target_names[y_pred[10]]

accuracy = accuracy_score(y_test, y_pred)
print(f"\nAccuracy: {accuracy * 100:.2f}%")
# Out:
# Correct Predictions:
# Sample 0: Predicted = versicolor, Actual = versicolor
# Sample 1: Predicted = setosa, Actual = setosa
# Sample 2: Predicted = virginica, Actual = virginica
# Sample 3: Predicted = versicolor, Actual = versicolor
# Sample 4: Predicted = versicolor, Actual = versicolor
# Sample 5: Predicted = setosa, Actual = setosa
# Sample 6: Predicted = versicolor, Actual = versicolor
# Sample 7: Predicted = virginica, Actual = virginica
# Sample 8: Predicted = versicolor, Actual = versicolor
# Sample 9: Predicted = versicolor, Actual = versicolor
# Sample 10: Predicted = virginica, Actual = virginica
# Sample 11: Predicted = setosa, Actual = setosa
# Sample 12: Predicted = setosa, Actual = setosa
# Sample 13: Predicted = setosa, Actual = setosa
# Sample 14: Predicted = setosa, Actual = setosa
# Sample 16: Predicted = virginica, Actual = virginica
# Sample 17: Predicted = versicolor, Actual = versicolor
# Sample 18: Predicted = versicolor, Actual = versicolor
# Sample 19: Predicted = virginica, Actual = virginica
# Sample 20: Predicted = setosa, Actual = setosa
# Sample 21: Predicted = virginica, Actual = virginica
# Sample 22: Predicted = setosa, Actual = setosa
# Sample 23: Predicted = virginica, Actual = virginica
# Sample 24: Predicted = virginica, Actual = virginica
# Sample 25: Predicted = virginica, Actual = virginica
# Sample 26: Predicted = virginica, Actual = virginica
# Sample 27: Predicted = virginica, Actual = virginica
# Sample 28: Predicted = setosa, Actual = setosa
# Sample 29: Predicted = setosa, Actual = setosa
# Sample 30: Predicted = setosa, Actual = setosa
# Sample 31: Predicted = setosa, Actual = setosa
# Sample 32: Predicted = versicolor, Actual = versicolor
# Sample 33: Predicted = setosa, Actual = setosa
# Sample 34: Predicted = setosa, Actual = setosa
# Sample 35: Predicted = virginica, Actual = virginica
# Sample 36: Predicted = versicolor, Actual = versicolor
# Sample 37: Predicted = setosa, Actual = setosa
# Sample 38: Predicted = setosa, Actual = setosa
# Sample 39: Predicted = setosa, Actual = setosa
# Sample 40: Predicted = virginica, Actual = virginica
# Sample 41: Predicted = versicolor, Actual = versicolor
# Sample 42: Predicted = versicolor, Actual = versicolor
# Sample 43: Predicted = setosa, Actual = setosa
# Sample 44: Predicted = setosa, Actual = setosa
# Sample 45: Predicted = versicolor, Actual = versicolor
# Sample 47: Predicted = virginica, Actual = virginica
# Sample 48: Predicted = versicolor, Actual = versicolor
# Sample 49: Predicted = virginica, Actual = virginica
# Sample 50: Predicted = versicolor, Actual = versicolor
# Sample 51: Predicted = virginica, Actual = virginica
# Sample 52: Predicted = versicolor, Actual = versicolor
# Sample 53: Predicted = setosa, Actual = setosa
# Sample 54: Predicted = virginica, Actual = virginica
# Sample 55: Predicted = versicolor, Actual = versicolor
# Sample 56: Predicted = setosa, Actual = setosa
# Sample 57: Predicted = setosa, Actual = setosa
# Sample 58: Predicted = setosa, Actual = setosa
# Sample 59: Predicted = versicolor, Actual = versicolor
#
# Wrong Predictions:
# Sample 15: Predicted = virginica, Actual = versicolor
# Sample 46: Predicted = versicolor, Actual = virginica
#
# Accuracy: 96.67%
